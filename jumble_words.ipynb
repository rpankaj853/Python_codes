# %%
from itertools import permutations

val = input()

for i in range(3,len(val)+1):
    
    per = permutations(val,i)

    for i in per:
    
        print(''.join(i))
# Out:
# balde
# bal
# bad
# bae
# bla
# bld
# ble
# bda
# bdl
# bde
# bea
# bel
# bed
# abl
# abd
# abe
# alb
# ald
# ale
# adb
# adl
# ade
# aeb
# ael
# aed
# lba
# lbd
# lbe
# lab
# lad
# lae
# ldb
# lda
# lde
# leb
# lea
# led
# dba
# dbl
# dbe
# dab
# dal
# dae
# dlb
# dla
# dle
# deb
# dea
# del
# eba
# ebl
# ebd
# eab
# eal
# ead
# elb
# ela
# eld
# edb
# eda
# edl
# bald
# bale
# badl
# bade
# bael
# baed
# blad
# blae
# blda
# blde
# blea
# bled
# bdal
# bdae
# bdla
# bdle
# bdea
# bdel
# beal
# bead
# bela
# beld
# beda
# bedl
# abld
# able
# abdl
# abde
# abel
# abed
# albd
# albe
# aldb
# alde
# aleb
# aled
# adbl
# adbe
# adlb
# adle
# adeb
# adel
# aebl
# aebd
# aelb
# aeld
# aedb
# aedl
# lbad
# lbae
# lbda
# lbde
# lbea
# lbed
# labd
# labe
# ladb
# lade
# laeb
# laed
# ldba
# ldbe
# ldab
# ldae
# ldeb
# ldea
# leba
# lebd
# leab
# lead
# ledb
# leda
# dbal
# dbae
# dbla
# dble
# dbea
# dbel
# dabl
# dabe
# dalb
# dale
# daeb
# dael
# dlba
# dlbe
# dlab
# dlae
# dleb
# dlea
# ...
